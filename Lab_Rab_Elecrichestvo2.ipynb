# %%
import numpy as np
from array import *
import math
import matplotlib.pyplot as plt

x =[]
y =[]
x1 =[]
y1 =[]
x2 =[]
y2 =[]




path1 = 'C:\\Users\\Иван\\Downloads\\3.1.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x1.append(float(values[0])) 
    y1.append(float(values[1])) 
    x2.append(float(values[2]))
    y2.append(float(values[3]))
    

x1 = np.array(x1)
x2 = np.array(x2)
y1 = np.array(y1)
y2 = np.array(y2)

kor1 = []
kor2 = []
tau = 10
dx = x1[2] - x1[1]
for i in range(len(y1)-tau):
    kor1.append(y1[i]*y1[i+tau]*dx)

for i in range(len(y2)-tau):
    kor2.append(y2[i]*y2[i+tau]*dx)
    
plt.plot (x1, y1)
plt.plot (x2, y2, 'r')
plt.show()
x1 = x1[:(len(x1)-tau)]
x2 = x2[:(len(x2)-tau)]
plt.plot (x1, kor1)
plt.plot (x2, kor2, 'r')

# %%
#Задание 3

# %%
import numpy as np
import math
from array import *
import matplotlib.pyplot as plt


x1 =[]
y1 =[]
x2 =[]
y2 =[]

x3 =[]
y3 =[]
x4 =[]
y4 =[]


# кф корреляции мощности
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.2.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x1.append(float(values[0])) 
    y1.append(float(values[1])) 
    x2.append(float(values[2]))
    y2.append(float(values[3]))
    

x1 = np.array(x1)
x2 = np.array(x2)
y1 = np.array(y1)
y2 = np.array(y2)
# кф корреляции комплексной амлитуды
path2 = 'C:\\Users\\Иван\\Downloads\\3_3.2.txt'
with open( path2,'r') as f:
  for line in f:
    values = line.split()
    x3.append(float(values[0])) 
    y3.append(float(values[1])) 
    x4.append(float(values[2]))
    y4.append(float(values[3]))
    

x3 = np.array(x3)
x4 = np.array(x4)
y3 = np.array(y3)
y4 = np.array(y4)
ylg1 = []
ylg2 = []
ylg3 = []
ylg4 = []
ykv3=[]
ykv4=[]
'''
for i in range(len(y1)):
    ylg1.append( 10*math.log10(y1[i]) )
for i in range(len(y2)):
    ylg2.append( 10*math.log10(y2[i]) )
'''
''' 
for i in range(len(y3)):
    ylg3.append( 10*math.log10(y3[i]) )
for i in range(len(y4)):
    ylg4.append( 10*math.log10(y4[i]) )
'''
for i in range(len(y3)):
    ykv3.append( abs(y3[i])**2)
    
for i in range(len(y4)):
    ykv4.append( abs(y4[i])**2)
    
plt.plot (x1, y1)
plt.plot (x2, y2, 'r')
plt.title('ρ_pp (τ)' )
plt.show()
xp1 = x1
yp1 = abs(y1)
xp2= x2
yp2 = abs(y2)
plt.plot (x3, y3)
plt.plot (x4, y4, 'r')
plt.title ('ρ_zz (τ)')
plt.show()
'''
for i in range(len(ykv3)):
    ykv3[i] = ykv3[i]/max(ykv3)
for i in range(len(ykv4)):
    ykv4[i] = ykv4[i]/max(ykv4)
'''    
plt.plot (x1, y1, 'b')
plt.plot (x2, y2, 'r')
plt.plot (x3, ykv3, '--b')
plt.plot (x4, ykv4, '--r')
plt.title ('ρ_pp (τ)=|ρ_zz (τ)|^2')
plt.show()

# %%
#Задание 4

# %%
import numpy as np
from array import *
import math
import matplotlib.pyplot as plt

ykv1=[]
ykv2=[]
x1 =[]
y1 =[]
x2 =[]
y2 =[]

x3 =[]
y3 =[]
x4 =[]
y4 =[]
ykv3=[]
ykv4=[]


path1 = 'C:\\Users\\Иван\\Downloads\\4_2.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x1.append(float(values[0])) 
    y1.append(float(values[1])) 
    x2.append(float(values[2]))
    y2.append(float(values[3]))
    
# коэф корреляции комплексной амлитуды
x1 = np.array(x1)
x2 = np.array(x2)
y1 = np.array(y1)
y2 = np.array(y2)

path2 = 'C:\\Users\\Иван\\Downloads\\4_3.txt'
with open( path2,'r') as f:
  for line in f:
    values = line.split()
    x3.append(float(values[0])) 
    y3.append(float(values[1])) 
    x4.append(float(values[2]))
    y4.append(float(values[3]))
    
# коэф корреляции  амлитуды 
x3 = np.array(x3)
x4 = np.array(x4)
y3 = np.array(y3)
y4 = np.array(y4)
ylg3 = []
ylg4 = []
for i in range(len(y3)):
    ylg3.append( 10*math.log10(y3[i]) )
for i in range(len(y4)):
    ylg4.append( 10*math.log10(y4[i]) )

for i in range(len(ylg3)):
    ykv3.append( abs(ylg3[i])**2)
    
for i in range(len(ylg4)):
    ykv4.append( abs(ylg4[i])**2)
    
plt.plot (x1, y1)
plt.plot (x2, y2, 'r')
plt.title('ρ_AA (τ) ')
plt.show()
ylg1 = []
ylg2 = []
for i in range(len(y1)):
    ylg1.append( 10*math.log10(y1[i]) )
for i in range(len(y2)):
    ylg2.append( 10*math.log10(y2[i]) )
'''
plt.show()
plt.plot (x3, y3)
plt.plot (x4, y4, 'r')
plt.title('ρ_zz (τ)')
plt.show()

plt.plot (x1, y1, 'b')
plt.plot (x2, y2, 'r')
plt.plot (x3, ykv1, '--b')
plt.plot (x4, ykv2, '--r')
plt.title('|ρ_zz (τ)|**2 = ρ_AA (τ) ')

plt.show()
plt.plot (x1, y1, 'b')
plt.plot (x2, y2, 'r')
plt.plot (x3, y3, '--b')
plt.plot (x4, y4, '--r')
plt.title('|ρ_zz (τ)| = ρ_AA (τ) ')
plt.show(
'''
    
plt.plot (x1, y1, 'b')
plt.plot (x2, y2, 'r')
plt.plot (xp1, yp1, '--b')
plt.plot (xp2, yp2, '--r')
plt.title('ρ_AA (τ) = |ρ_pp (τ)| ')
plt.show()
#plt.yscale("log")
#plt.xscale("log")
plt.plot(x1, ylg1, 'b')
plt.plot (x2, ylg2, 'r')
plt.show()

# %%
#Задание 3

# %%
import numpy as np
import math
from array import *
import matplotlib.pyplot as plt


x1 =[]
y1 =[]
x11 =[]
y11 =[]

x2 =[]
y2 =[]
x22 =[]
y22 =[]

x3 =[]
y3 =[]
x33 =[]
y33 =[]

x4 =[]
y4 =[]
x44 =[]
y44 =[]

x5 =[]
y5 =[]
x55 =[]
y55 =[]

x6 =[]
y6 =[]
x66 =[]
y66 =[]

x7 =[]
y7 =[]
x77 =[]
y77 =[]

x8 =[]
y8 =[]
x88 =[]
y88 =[]

x9 =[]
y9 =[]
x99 =[]
y99 =[]

x10 =[]
y10 =[]
x1010 =[]
y1010 =[]


path1 = 'C:\\Users\\Иван\\Downloads\\3_2.1.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x1.append(float(values[0])) 
    y1.append(float(values[1])) 
    x11.append(float(values[2]))
    y11.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.2.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x2.append(float(values[0])) 
    y2.append(float(values[1])) 
    x22.append(float(values[2]))
    y22.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.3.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x3.append(float(values[0])) 
    y3.append(float(values[1])) 
    x33.append(float(values[2]))
    y33.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.4.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x4.append(float(values[0])) 
    y4.append(float(values[1])) 
    x44.append(float(values[2]))
    y44.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.5.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x5.append(float(values[0])) 
    y5.append(float(values[1])) 
    x55.append(float(values[2]))
    y55.append(float(values[3]))

path1 = 'C:\\Users\\Иван\\Downloads\\3_2.6.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x6.append(float(values[0])) 
    y6.append(float(values[1])) 
    x66.append(float(values[2]))
    y66.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.7.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x7.append(float(values[0])) 
    y7.append(float(values[1])) 
    x77.append(float(values[2]))
    y77.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.8.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x8.append(float(values[0])) 
    y8.append(float(values[1])) 
    x88.append(float(values[2]))
    y88.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.9.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x9.append(float(values[0])) 
    y9.append(float(values[1])) 
    x99.append(float(values[2]))
    y99.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_2.10.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x10.append(float(values[0])) 
    y10.append(float(values[1])) 
    x1010.append(float(values[2]))
    y1010.append(float(values[3]))
#усреднение 1 и 3 столюцов
xpp1 = []
xpp2 = []
for i in range(len(x1)):
    xpp1.append ( (x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i]+x9[i]+x10[i])/10 )
    xpp2.append ( (x11[i]+x22[i]+x33[i]+x44[i]+x55[i]+x66[i]+x77[i]+x88[i]+x99[i]+x1010[i])/10 )
#усреднение 2 и 4 столбцов
ypp1 = []
ypp2 = []
for i in range (len(y1)): 
    ypp1.append ( (y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i]+y9[i]+y10[i])/10 )
    ypp2.append ( (y11[i]+y22[i]+y33[i]+y44[i]+y55[i]+y66[i]+y77[i]+y88[i]+y99[i]+y1010[i])/10 )

plt.plot(xpp1, ypp1)
plt.plot(xpp2, ypp2)

# %%
import numpy as np
import math
from array import *
import matplotlib.pyplot as plt


x1 =[]
y1 =[]
x11 =[]
y11 =[]

x2 =[]
y2 =[]
x22 =[]
y22 =[]

x3 =[]
y3 =[]
x33 =[]
y33 =[]

x4 =[]
y4 =[]
x44 =[]
y44 =[]

x5 =[]
y5 =[]
x55 =[]
y55 =[]

x6 =[]
y6 =[]
x66 =[]
y66 =[]

x7 =[]
y7 =[]
x77 =[]
y77 =[]

x8 =[]
y8 =[]
x88 =[]
y88 =[]

x9 =[]
y9 =[]
x99 =[]
y99 =[]

x10 =[]
y10 =[]
x1010 =[]
y1010 =[]


path1 = 'C:\\Users\\Иван\\Downloads\\3_3.1.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x1.append(float(values[0])) 
    y1.append(float(values[1])) 
    x11.append(float(values[2]))
    y11.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_3.2.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x2.append(float(values[0])) 
    y2.append(float(values[1])) 
    x22.append(float(values[2]))
    y22.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_3.3.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x3.append(float(values[0])) 
    y3.append(float(values[1])) 
    x33.append(float(values[2]))
    y33.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_3.4.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x4.append(float(values[0])) 
    y4.append(float(values[1])) 
    x44.append(float(values[2]))
    y44.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_3.5.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x5.append(float(values[0])) 
    y5.append(float(values[1])) 
    x55.append(float(values[2]))
    y55.append(float(values[3]))

path1 = 'C:\\Users\\Иван\\Downloads\\3_3.6.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x6.append(float(values[0])) 
    y6.append(float(values[1])) 
    x66.append(float(values[2]))
    y66.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_3.7.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x7.append(float(values[0])) 
    y7.append(float(values[1])) 
    x77.append(float(values[2]))
    y77.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_3.8.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x8.append(float(values[0])) 
    y8.append(float(values[1])) 
    x88.append(float(values[2]))
    y88.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_3.9.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x9.append(float(values[0])) 
    y9.append(float(values[1])) 
    x99.append(float(values[2]))
    y99.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\3_3.10.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x10.append(float(values[0])) 
    y10.append(float(values[1])) 
    x1010.append(float(values[2]))
    y1010.append(float(values[3]))
#усреднение 1 и 3 столюцов
xzz1 = []
xzz2 = []
for i in range(len(x1)):
    xzz1.append ( (x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i]+x9[i]+x10[i])/10 )
    xzz2.append ( (x11[i]+x22[i]+x33[i]+x44[i]+x55[i]+x66[i]+x77[i]+x88[i]+x99[i]+x1010[i])/10 )
#усреднение 2 и 4 столбцов
yzz1 = []
yzz2 = []
for i in range (len(y1)): 
    yzz1.append ( (y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i]+y9[i]+y10[i])/10 )
    yzz2.append ( (y11[i]+y22[i]+y33[i]+y44[i]+y55[i]+y66[i]+y77[i]+y88[i]+y99[i]+y1010[i])/10 )


for i in range(len(yzz1)):
    yzz1[i] = abs(yzz1[i])**2
    yzz2[i] = abs(yzz2[i])**2

plt.plot(xzz1, yzz1)
plt.plot(xzz2, yzz2)

# %%
#объединение графиков
# 3 Задание
plt.plot(xpp1, ypp1, color = 'r')
plt.plot(xpp2, ypp2, color = 'b')
plt.plot(xzz1, yzz1, '--r')
plt.plot(xzz2, yzz2, '--b')
plt.title('p_pp = |p_zz|^2')
plt.grid()
plt.show()

# %%
#задание №4

# %%
import numpy as np
import math
from array import *
import matplotlib.pyplot as plt


x1 =[]
y1 =[]
x11 =[]
y11 =[]

x2 =[]
y2 =[]
x22 =[]
y22 =[]

x3 =[]
y3 =[]
x33 =[]
y33 =[]

x4 =[]
y4 =[]
x44 =[]
y44 =[]

x5 =[]
y5 =[]
x55 =[]
y55 =[]

x6 =[]
y6 =[]
x66 =[]
y66 =[]

x7 =[]
y7 =[]
x77 =[]
y77 =[]

x8 =[]
y8 =[]
x88 =[]
y88 =[]

x9 =[]
y9 =[]
x99 =[]
y99 =[]

x10 =[]
y10 =[]
x1010 =[]
y1010 =[]


path1 = 'C:\\Users\\Иван\\Downloads\\4_2.1.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x1.append(float(values[0])) 
    y1.append(float(values[1])) 
    x11.append(float(values[2]))
    y11.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_2.2.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x2.append(float(values[0])) 
    y2.append(float(values[1])) 
    x22.append(float(values[2]))
    y22.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_2.3.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x3.append(float(values[0])) 
    y3.append(float(values[1])) 
    x33.append(float(values[2]))
    y33.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_2.4.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x4.append(float(values[0])) 
    y4.append(float(values[1])) 
    x44.append(float(values[2]))
    y44.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_2.5.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x5.append(float(values[0])) 
    y5.append(float(values[1])) 
    x55.append(float(values[2]))
    y55.append(float(values[3]))

path1 = 'C:\\Users\\Иван\\Downloads\\4_2.6.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x6.append(float(values[0])) 
    y6.append(float(values[1])) 
    x66.append(float(values[2]))
    y66.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_2.7.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x7.append(float(values[0])) 
    y7.append(float(values[1])) 
    x77.append(float(values[2]))
    y77.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_2.8.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x8.append(float(values[0])) 
    y8.append(float(values[1])) 
    x88.append(float(values[2]))
    y88.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_2.9.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x9.append(float(values[0])) 
    y9.append(float(values[1])) 
    x99.append(float(values[2]))
    y99.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_2.10.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x10.append(float(values[0])) 
    y10.append(float(values[1])) 
    x1010.append(float(values[2]))
    y1010.append(float(values[3]))
#усреднение 1 и 3 столюцов
xp1 = []
xp2 = []
for i in range(len(x1)):
    xp1.append ( (x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i]+x9[i]+x10[i])/10 )
    xp2.append ( (x11[i]+x22[i]+x33[i]+x44[i]+x55[i]+x66[i]+x77[i]+x88[i]+x99[i]+x1010[i])/10 )
#усреднение 2 и 4 столбцов
yp1 = []
yp2 = []
for i in range (len(y1)): 
    yp1.append ( (y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i]+y9[i]+y10[i])/10 )
    yp2.append ( (y11[i]+y22[i]+y33[i]+y44[i]+y55[i]+y66[i]+y77[i]+y88[i]+y99[i]+y1010[i])/10 )

plt.plot(xp1, yp1)
plt.plot(xp2, yp2)

# %%
import numpy as np
import math
from array import *
import matplotlib.pyplot as plt


x1 =[]
y1 =[]
x11 =[]
y11 =[]

x2 =[]
y2 =[]
x22 =[]
y22 =[]

x3 =[]
y3 =[]
x33 =[]
y33 =[]

x4 =[]
y4 =[]
x44 =[]
y44 =[]

x5 =[]
y5 =[]
x55 =[]
y55 =[]

x6 =[]
y6 =[]
x66 =[]
y66 =[]

x7 =[]
y7 =[]
x77 =[]
y77 =[]

x8 =[]
y8 =[]
x88 =[]
y88 =[]

x9 =[]
y9 =[]
x99 =[]
y99 =[]

x10 =[]
y10 =[]
x1010 =[]
y1010 =[]


path1 = 'C:\\Users\\Иван\\Downloads\\4_3.1.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x1.append(float(values[0])) 
    y1.append(float(values[1])) 
    x11.append(float(values[2]))
    y11.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_3.2.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x2.append(float(values[0])) 
    y2.append(float(values[1])) 
    x22.append(float(values[2]))
    y22.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_3.3.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x3.append(float(values[0])) 
    y3.append(float(values[1])) 
    x33.append(float(values[2]))
    y33.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_3.4.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x4.append(float(values[0])) 
    y4.append(float(values[1])) 
    x44.append(float(values[2]))
    y44.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_3.5.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x5.append(float(values[0])) 
    y5.append(float(values[1])) 
    x55.append(float(values[2]))
    y55.append(float(values[3]))

path1 = 'C:\\Users\\Иван\\Downloads\\4_3.6.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x6.append(float(values[0])) 
    y6.append(float(values[1])) 
    x66.append(float(values[2]))
    y66.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_3.7.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x7.append(float(values[0])) 
    y7.append(float(values[1])) 
    x77.append(float(values[2]))
    y77.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_3.8.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x8.append(float(values[0])) 
    y8.append(float(values[1])) 
    x88.append(float(values[2]))
    y88.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_3.9.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x9.append(float(values[0])) 
    y9.append(float(values[1])) 
    x99.append(float(values[2]))
    y99.append(float(values[3]))
    
path1 = 'C:\\Users\\Иван\\Downloads\\4_3.10.txt'
with open( path1,'r') as f:
  for line in f:
    values = line.split()
    x10.append(float(values[0])) 
    y10.append(float(values[1])) 
    x1010.append(float(values[2]))
    y1010.append(float(values[3]))
#усреднение 1 и 3 столюцов
xz1 = []
xz2 = []
for i in range(len(x1)):
    xz1.append ( (x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i]+x9[i]+x10[i])/10 )
    xz2.append ( (x11[i]+x22[i]+x33[i]+x44[i]+x55[i]+x66[i]+x77[i]+x88[i]+x99[i]+x1010[i])/10 )
#усреднение 2 и 4 столбцов
yz1 = []
yz2 = []

for i in range (len(y1)): 
    yz1.append ( (y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i]+y9[i]+y10[i])/10 )
    yz2.append ( (y11[i]+y22[i]+y33[i]+y44[i]+y55[i]+y66[i]+y77[i]+y88[i]+y99[i]+y1010[i])/10 )

plt.plot(xz1, yz1)
plt.plot(xz2, yz2)

# %%
#объединение графиков
# 4 Задание
plt.plot(xp1, yp1, color = 'r')
plt.plot(xp2, yp2, color = 'b')
plt.plot(xz1, yz1, '--r')
plt.plot(xz2, yz2, '--b')
plt.title('p_AA = |p_pp|')
plt.grid()
plt.show()
